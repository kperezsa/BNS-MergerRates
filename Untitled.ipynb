# %%
# %load exp_map_1.py
import numpy as np
import matplotlib.pyplot as plt
from astropy.io import ascii
import astropy.coordinates as coord
import astropy.units as u
import ephem

def make_exp_map(data_file='decam_exposures_i_min30sec_Sep2016.csv',
                 title='DECam i-band sky coverage as of September 2016',
                 color=plt.cm.Blues,
                 out_file='test.pdf',
                 ra_in_degrees=True,
                 width_of_mw_band=10.):

    data = ascii.read(data_file,header_start=0)
    ra = coord.Angle(data['ra'].filled(np.nan)*u.degree)
    ra = ra.wrap_at(180*u.degree)
    dec = coord.Angle(data['dec'].filled(np.nan)*u.degree)
    exptime = data['exptime'].filled(np.nan)

    fig = plt.figure(figsize=(8,6))
    ax = fig.add_subplot(111, projection="mollweide")
    npix_ra=360/6 
    hb=ax.hexbin(ra.radian, dec.radian, C=exptime, gridsize=npix_ra, bins='log',
                 reduce_C_function=np.sum,cmap=color)
    cb=fig.colorbar(hb,orientation='horizontal',cax=fig.add_axes([0.2, 0.17, 0.6, 0.03]))
    cb.set_label('total exposure [log (exptime/sec)]')
    ax.set_title(title+'\n')
    ax.set_xlabel('RA')
    ax.set_ylabel('DEC')
    if not ra_in_degrees:
        ax.set_xticklabels(['14h','16h','18h','20h','22h','0h','2h','4h','6h','8h','10h'])
    ax.grid(True)

    ra_MW, dec_MW = the_galaxy_in_equatorial_coords(width_of_mw_band)
    for i in range(len(ra_MW)):
        ra = coord.Angle(ra_MW[i]*u.degree)
        ra = ra.wrap_at(180*u.degree)        
        dec = coord.Angle(dec_MW[i]*u.degree)
        slices = unlink_wrap(ra.radian)
        for slc in slices:
            ax.plot(ra.radian[slc],dec.radian[slc],'b',lw=2)        

#    ra_fields_hours={'F1': 10, 'F2': 16, 'F3': 22}
#    ra_fields_degrees={'F1': 150, 'F2': -120, 'F3': -30}
#    dec_fields_degrees={'F1': -15, 'F2': -15, 'F3': -15}
    ra_fields = np.array([150.,-120.,-30.])
    dec_fields = np.array([-15.,-15.,-15.])
    ra = coord.Angle(ra_fields*u.degree)
    ra = ra.wrap_at(180*u.degree)
    dec = coord.Angle(dec_fields*u.degree)
    ax.scatter(ra.radian,dec.radian,s=100,color='red',marker='D')

    fig.savefig(out_file)


def the_galaxy_in_equatorial_coords(width=0.):
    lon_array = np.arange(0,360)
    ra, dec = [] , []
    lat_list = [ -0.5*width, 0. , 0.5*width]
    for lat in lat_list:
        eq_array = np.zeros((360,2))
        for lon in lon_array:
            ga = ephem.Galactic(np.radians(lon), np.radians(lat))
            eq = ephem.Equatorial(ga)
            eq_array[lon] = np.degrees(eq.get())
        ra.append(eq_array[:,0])
        dec.append(eq_array[:,1])
    return ra,dec

def unlink_wrap(dat, lims=[-np.pi, np.pi], thresh = 0.95):
    """
    Iterate over contiguous regions of `dat` (i.e. where it does not
    jump from near one limit to the other).

    This function returns an iterator object that yields slice
    objects, which index the contiguous portions of `dat`.

    This function implicitly assumes that all points in `dat` fall
    within `lims`.

    """    
    jump = np.nonzero(np.abs(np.diff(dat)) > ((lims[1] - lims[0]) * thresh))[0]
    lasti = 0
    for ind in jump:
        yield slice(lasti, ind + 1)
        lasti = ind + 1
    yield slice(lasti, len(dat))




filters=['g','r','i','z','VR']

colormaps={'g': plt.cm.Greens,
           'r': plt.cm.Oranges,
           'i': plt.cm.Purples,
           'z': plt.cm.Greys,
           'VR': plt.cm.Blues}



for b in filters:
    make_exp_map(data_file='decam_exposures_'+b+'_min30sec_Sep2016.csv',
                 title='DECam '+b+'-band sky coverage as of September 2016',
                 color=colormaps[b],
                 out_file='map_'+b+'_h.pdf',
                 ra_in_degrees=False,
                 width_of_mw_band=20.)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-1-daed8cff9df0> in <module>()
#     108                  out_file='map_'+b+'_h.pdf',
#     109                  ra_in_degrees=False,
# --> 110                  width_of_mw_band=20.)
#     111
#     112
#
# <ipython-input-1-daed8cff9df0> in make_exp_map(data_file, title, color, out_file, ra_in_degrees, width_of_mw_band)
#      14                  width_of_mw_band=10.):
#      15
# ---> 16     data = ascii.read(data_file,header_start=0)
#      17     ra = coord.Angle(data['ra'].filled(np.nan)*u.degree)
#      18     ra = ra.wrap_at(180*u.degree)
#
# /Users/KarenPerezSarmiento/Library/Python/3.5/lib/python/site-packages/astropy/io/ascii/ui.py in read(table, guess, **kwargs)
#     320         # through below to the non-guess way so that any problems result in a
#     321         # more useful traceback.
# --> 322         dat = _guess(table, new_kwargs, format, fast_reader_param)
#     323         if dat is None:
#     324             guess = False
#
# /Users/KarenPerezSarmiento/Library/Python/3.5/lib/python/site-packages/astropy/io/ascii/ui.py in _guess(table, read_kwargs, format, fast_reader)
#     468             reader = get_reader(**guess_kwargs)
#     469             reader.guessing = True
# --> 470             dat = reader.read(table)
#     471             _read_trace.append({'kwargs': guess_kwargs, 'status': 'Success (guessing)',
#     472                                 'dt': '{0:.3f} ms'.format((time.time() - t0) * 1000)})
#
# /Users/KarenPerezSarmiento/Library/Python/3.5/lib/python/site-packages/astropy/io/ascii/core.py in read(self, table)
#    1142
#    1143         # Get a list of the lines (rows) in the table
# -> 1144         self.lines = self.inputter.get_lines(table)
#    1145
#    1146         # Set self.data.data_lines to a slice of lines contain the data rows
#
# /Users/KarenPerezSarmiento/Library/Python/3.5/lib/python/site-packages/astropy/io/ascii/core.py in get_lines(self, table)
#     281             if (hasattr(table, 'read') or
#     282                     ('\n' not in table + '' and '\r' not in table + '')):
# --> 283                 with get_readable_fileobj(table) as file_obj:
#     284                     table = file_obj.read()
#     285             lines = table.splitlines()
#
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/contextlib.py in __enter__(self)
#      57     def __enter__(self):
#      58         try:
# ---> 59             return next(self.gen)
#      60         except StopIteration:
#      61             raise RuntimeError("generator didn't yield") from None
#
# /Users/KarenPerezSarmiento/Library/Python/3.5/lib/python/site-packages/astropy/utils/data.py in get_readable_fileobj(name_or_obj, encoding, cache, show_progress, remote_timeout)
#     199             fileobj = open(name_or_obj, 'rb')
#     200         else:
# --> 201             fileobj = io.FileIO(name_or_obj, 'r')
#     202         if is_url and not cache:
#     203             delete_fds.append(fileobj)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'decam_exposures_g_min30sec_Sep2016.csv'
