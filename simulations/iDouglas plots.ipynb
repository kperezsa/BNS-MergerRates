# %%
# %matplotlib notebook
import sys
sys.path.append("../research2017/ELVIS_HALO_Catalogs/IsolatedCatalogs")
import mainfunction as mn
filename='../ELVIS_HALO_Catalogs/IsolatedCatalogs/iDouglas.txt'

mn.massPlot(filename)

mn.positionPlotCenter(filename)

mn.positionPlot(filename)

mn.distAnalogs(filename)
# Out:
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
# array([[  8.51421600e+06,   3.86967531e-02,   3.51970000e+01,
#           3.51951000e+01,   3.51791400e+01],
#        [  8.51424300e+06,   2.91958233e-02,   3.52153700e+01,
#           3.52022100e+01,   3.51838200e+01],
#        [  8.51428400e+06,   4.92221271e-02,   3.51872000e+01,
#           3.51962700e+01,   3.51710400e+01],
#        [  8.51440900e+06,   3.43226077e-02,   3.51939300e+01,
#           3.51878000e+01,   3.51932000e+01],
#        [  8.51456700e+06,   4.22726898e-02,   3.52011400e+01,
#           3.51928000e+01,   3.51746200e+01],
#        [  8.51470100e+06,   3.24873191e-02,   3.51933400e+01,
#           3.52043400e+01,   3.51850800e+01],
#        [  8.51483900e+06,   4.42000204e-02,   3.52414200e+01,
#           3.52383000e+01,   3.51935500e+01],
# ...
